# %%
# Import packages
from uszipcode import ZipcodeSearchEngine
import pandas as pd
import numpy as np

# %%
market = pd.read_csv("data/farmersmarkets-or.csv")
market.head()
# Out:
#       FMID                                       MarketName  \
# 0  1018261  Caledonia Farmers Market Association - Danville
# 1  1018318                Stearns Homestead Farmers' Market
# 2  1009364                106 S. Main Street Farmers Market
# 3  1010691              10th Steet Community Farmers Market
# 4  1002454                             112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# 2                                                NaN     NaN     NaN
# ...

# %%
market.iloc[1]["zip"]
# Out:
# nan

# %%
zip_null_idx = np.where(pd.isnull(market["zip"]))
zip_null_idx[0][:10]
print(len(*zip_null_idx))
# Out:
# 961

# %%
search = ZipcodeSearchEngine()
for i in list(*zip_null_idx):
    print(i)
    temp = market.iloc[i]
    x= temp["x"]
    y= temp["y"]
    if(pd.notna([x,y]).all()):
        res = search.by_coordinate(y,x, radius=100, returns=5)
        for result in res:
            if(result["City"]==temp["city"]):
                # put new zipcode to the data
                market.loc[i, 'zip'] = result["Zipcode"]
                break
            else:
                market.loc[i, 'zip'] = result["Zipcode"]
                break
# Out:
# 1
# 36
# 45
# 56
# 59
# 65
# 67
# 69
# 71
# 76
# 79
# 96
# 99
# 102
# 106
# 110
# 114
# 118
# 119
# 129
# 137
# 155
# 166
# 174
# 175
# 198
# 200
# 209
# 211
# 212
# 224
# 230
# 262
# 271
# 276
# 291
# 298
# 299
# 348
# 365
# 373
# 383
# 387
# 425
# 431
# 440
# 489
# 496
# 499
# 502
# 514
# 546
# 566
# 582
# 600
# 606
# 626
# 639
# 645
# 652
# 710
# 716
# 726
# 734
# 735
# 750
# 754
# 759
# 772
# 774
# 780
# 783
# 786
# 791
# 796
# 799
# 823
# 824
# 841
# 853
# 871
# 883
# 902
# 903
# 937
# 965
# 968
# 1007
# 1012
# 1027
# 1030
# 1053
# 1066
# 1078
# 1079
# 1092
# 1094
# 1104
# 1127
# 1132
# 1137
# 1138
# 1141
# 1155
# 1158
# 1171
# 1176
# 1186
# 1187
# 1189
# 1192
# 1212
# 1216
# 1227
# 1237
# 1241
# 1250
# 1268
# 1270
# 1276
# 1279
# 1285
# 1293
# 1305
# 1311
# 1322
# 1324
# 1326
# 1358
# 1382
# 1389
# 1396
# 1400
# 1403
# 1413
# 1418
# 1425
# 1426
# 1429
# 1432
# 1439
# 1445
# 1447
# 1456
# 1457
# 1472
# 1528
# 1535
# 1551
# 1555
# 1563
# 1565
# 1585
# 1590
# 1610
# 1611
# 1612
# ...

# %%
zip_still_null =np.where(pd.isnull(market["zip"]))
print(len(*zip_still_null))
print(zip_still_null)
# Out:
# 27
# (array([1137, 1894, 2499, 2504, 2507, 2523, 2736, 2857, 2910, 3046, 3078,
#        3192, 3229, 3646, 3690, 4858, 4998, 5712, 6257, 6403, 6643, 7223,
#        7695, 7752, 7906, 8409, 8655], dtype=int64),)

# %%
# x or y values are null for those 27 datasets
for i in list(*zip_still_null):
    x = market.loc[i, "x"]
    print(x)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
